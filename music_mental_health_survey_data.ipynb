# %% [markdown]
# <a href="https://colab.research.google.com/github/MinsooKwak/Kaggle_note/blob/main/music_mental_health_survey_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install Kaggle / Download Dataset

# %%
#kaggle install
#!pip install kaggle

# %%
from google.colab import files
files.upload()

# %%
# !mkdir -p ~/.kaggle

# %%
# !ls -al ~/
# Out:
# total 64
# drwx------ 1 root root 4096 Jan 26 14:02 .
# drwxr-xr-x 1 root root 4096 Jan 26 13:59 ..
# -r-xr-xr-x 1 root root 1169 Jan  1  2000 .bashrc
# drwxr-xr-x 1 root root 4096 Jan 24 14:50 .cache
# drwx------ 4 root root 4096 Jan 24 14:50 .config
# drwxr-xr-x 5 root root 4096 Jan 24 14:49 .ipython
# drwx------ 2 root root 4096 Jan 24 14:49 .jupyter
# drwxr-xr-x 2 root root 4096 Jan 26 14:02 .kaggle
# drwxr-xr-x 2 root root 4096 Jan 24 14:48 .keras
# drwxr-xr-x 1 root root 4096 Jan 24 14:49 .local
# drwxr-xr-x 4 root root 4096 Jan 24 14:49 .npm
# -rw-r--r-- 1 root root  161 Dec  5  2019 .profile
# -r-xr-xr-x 1 root root  254 Jan  1  2000 .tmux.conf
# -rw-r--r-- 1 root root  165 Jan 24 14:49 .wget-hsts

# %%
#인증키 복사 후 속성 변경
# !cp kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 /root/.kaggle/kaggle.json
# !ls -al ~/.kaggle/
# Out:
# total 16
# drwxr-xr-x 2 root root 4096 Jan 26 14:02 .
# drwx------ 1 root root 4096 Jan 26 14:02 ..
# -rw------- 1 root root   72 Jan 26 14:02 kaggle.json

# %%
# !kaggle competitions list

# %%
# !kaggle datasets download -d catherinerasgaitis/mxmh-survey-results
# Out:
# ...
#   0% 0.00/22.4k [00:00<?, ?B/s]
# 100% 22.4k/22.4k [00:00<00:00, 15.6MB/s]

# %%
# !ls -al
# Out:
# total 48
# drwxr-xr-x 1 root root  4096 Jan 26 14:02 .
# drwxr-xr-x 1 root root  4096 Jan 26 13:59 ..
# drwxr-xr-x 4 root root  4096 Jan 24 14:37 .config
# drwxr-xr-x 2 root root  4096 Jan 26 14:02 .ipynb_checkpoints
# -rw-r--r-- 1 root root    72 Jan 26 14:02 kaggle.json
# -rw-r--r-- 1 root root 22912 Jan 26 14:02 mxmh-survey-results.zip
# drwxr-xr-x 1 root root  4096 Jan 24 14:38 sample_data

# %%
# !unzip '*zip'
# !ls
# Out:
# Archive:  mxmh-survey-results.zip
#   inflating: mxmh_survey_results.csv
# kaggle.json  mxmh_survey_results.csv  mxmh-survey-results.zip  sample_data

# %% [markdown]
# ## Import Dataset

# %% [markdown]
# https://www.kaggle.com/code/totoro29/music-and-mental-condition 참고 스터디

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/mxmh_survey_results.csv')
df.head(3)
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0               Yes  ...        Sometimes  Very frequently            Never
# 1                No  ...        Sometimes           Rarely  Very frequently
# 2               Yes  ...            Never           Rarely           Rarely
#
#   Frequency [Video game music] Anxiety Depression Insomnia  OCD Music effects  \
# ...

# %%
print(f'data shape : {df.shape}')
# Out:
# data shape : (736, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
# ...

# %%
df.describe().T
# Out:
#                count          mean           std   min    25%    50%    75%  \
# Age            735.0  2.520680e+01  1.205497e+01  10.0   18.0   21.0   28.0
# Hours per day  736.0  3.572758e+00  3.028199e+00   0.0    2.0    3.0    5.0
# BPM            629.0  1.589948e+06  3.987261e+07   0.0  100.0  120.0  144.0
# Anxiety        736.0  5.837636e+00  2.793054e+00   0.0    4.0    6.0    8.0
# Depression     736.0  4.796196e+00  3.028870e+00   0.0    2.0    5.0    7.0
# Insomnia       736.0  3.738451e+00  3.088689e+00   0.0    1.0    3.0    6.0
# OCD            736.0  2.637228e+00  2.842017e+00   0.0    0.0    2.0    5.0
#
#                        max
# Age                   89.0
# Hours per day         24.0
# BPM            999999999.0
# Anxiety               10.0
# Depression            10.0
# Insomnia              10.0
# OCD                   10.0

# %%
df.describe(exclude='number').T
# Out:
#                              count unique                 top freq
# Timestamp                      736    735  8/28/2022 16:15:08    2
# Primary streaming service      735      6             Spotify  458
# While working                  733      2                 Yes  579
# Instrumentalist                732      2                  No  497
# Composer                       735      2                  No  609
# Fav genre                      736     16                Rock  188
# Exploratory                    736      2                 Yes  525
# Foreign languages              732      2                 Yes  404
# Frequency [Classical]          736      4              Rarely  259
# Frequency [Country]            736      4               Never  343
# Frequency [EDM]                736      4               Never  307
# Frequency [Folk]               736      4               Never  292
# Frequency [Gospel]             736      4               Never  535
# ...
